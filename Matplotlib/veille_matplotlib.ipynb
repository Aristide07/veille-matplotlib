# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_table('heart.txt')
df
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin       100        234     A       A       156    non
# 1     41   feminin       130        204     A       C       172    non
# 2     58  masculin       150        270     A       C       111    oui
# 3     53  masculin       140        203     B       C       155    oui
# 4     41  masculin       130        214     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin       140        268     A       C       160    non
# 266   62  masculin       130        231     A       A       146    non
# 267   64  masculin       110        211     A       C       144    oui
# 268   63   feminin       150        407     A       C       154    non
# 269   35   feminin       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# ...

# %% [markdown]
# ## Liste de chaque données

# %%
list(df)
# Out:
# ['age',
#  'sexe',
#  'pression',
#  'cholester',
#  'sucre',
#  'electro',
#  'taux_max',
#  'angine',
#  'depression',
#  'pic',
#  'vaisseau',
#  'coeur']

# %%
df[['age']]
# Out:
#      age
# 0     58
# 1     41
# 2     58
# 3     53
# 4     41
# ..   ...
# 265   62
# 266   62
# 267   64
# 268   63
# 269   35
#
# [270 rows x 1 columns]

# %%
df[['sexe']]
# Out:
#          sexe
# 0    masculin
# 1     feminin
# 2    masculin
# 3    masculin
# 4    masculin
# ..        ...
# 265   feminin
# 266  masculin
# 267  masculin
# 268   feminin
# 269   feminin
#
# [270 rows x 1 columns]

# %%
df[['pression']]
# Out:
#      pression
# 0         100
# 1         130
# 2         150
# 3         140
# 4         130
# ..        ...
# 265       140
# 266       130
# 267       110
# 268       150
# 269       138
#
# [270 rows x 1 columns]

# %%
df[['cholester']]
# Out:
#      cholester
# 0          234
# 1          204
# 2          270
# 3          203
# 4          214
# ..         ...
# 265        268
# 266        231
# 267        211
# 268        407
# 269        183
#
# [270 rows x 1 columns]

# %%
df[['sucre']]
# Out:
#     sucre
# 0       A
# 1       A
# 2       A
# 3       B
# 4       A
# ..    ...
# 265     A
# 266     A
# 267     A
# 268     A
# 269     A
#
# [270 rows x 1 columns]

# %%
df[['electro']]
# Out:
#     electro
# 0         A
# 1         C
# 2         C
# 3         C
# 4         C
# ..      ...
# 265       C
# 266       A
# 267       C
# 268       C
# 269       A
#
# [270 rows x 1 columns]

# %%
df[['taux_max']]
# Out:
#      taux_max
# 0         156
# 1         172
# 2         111
# 3         155
# 4         168
# ..        ...
# 265       160
# 266       146
# 267       144
# 268       154
# 269       182
#
# [270 rows x 1 columns]

# %%
df[['angine']]
# Out:
#     angine
# 0      non
# 1      non
# 2      oui
# 3      oui
# 4      non
# ..     ...
# 265    non
# 266    non
# 267    oui
# 268    non
# 269    non
#
# [270 rows x 1 columns]

# %%
df[['depression']]

# %%
df[['pic']]

# %%
df[['vaisseau']]

# %%
df[['coeur']]
# Out:
#         coeur
# 0    presence
# 1     absence
# 2    presence
# 3    presence
# 4     absence
# ..        ...
# 265  presence
# 266   absence
# 267   absence
# 268  presence
# 269   absence
#
# [270 rows x 1 columns]

# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# ## Graphique de chaque variable

# %%
#garphique Age
plt.plot(df.age,'o', c='g')
plt.title('Age')
plt.show()

# %%
#garphique sexe
plt.hist(df['sexe'])
plt.title('sexe')
# Out:
# Text(0.5, 1.0, 'sexe')

# %%
#garphique pression
g_pression=plt.plot(df.pression,'o', c='m')
plt.title('Pression')
plt.show()

# %%
#garphique cholester
g_cholester=plt.plot(df.cholester,'o', c='springgreen')
plt.title('cholester')
plt.show()

# %%
#garphique sucre
plt.hist(df['sucre'])
plt.title('sucre')
# Out:
# Text(0.5, 1.0, 'sucre')

# %%
#garphique electro
plt.hist(df['electro'])
plt.title('electro')
# Out:
# Text(0.5, 1.0, 'electro')

# %%
#garphique taux_max
g_taux_max=plt.plot(df.taux_max,'o', c='mediumvioletred')
plt.title('Taux_max')
plt.show()

# %%
#garphique angine

plt.hist(df['angine'])
plt.title('Angine')
# Out:
# Text(0.5, 1.0, 'Angine')

# %%
#garphique depression
g_depression=plt.plot(df.depression,'o', c='purple')
plt.title('Depression')
plt.show()

# %%
#garphique pic
g_pic=plt.plot(df.pic,'o', c='dodgerblue')
plt.title('Pic')
plt.show()

# %%
#garphique vaisseau
g_vaisseau=plt.plot(df.vaisseau,'o', c='yellowgreen')
plt.title('Vaisseau')
plt.show()

# %%
#garphique coeur
plt.hist(df['coeur'])
plt.title('Coeur')
# Out:
# Text(0.5, 1.0, 'Coeur')

# %% [markdown]
# ## Affichage variable quantit - quantit

# %%
#age_pression
df.plot.scatter(x='age', y='pression')
# Out:
# <AxesSubplot:xlabel='age', ylabel='pression'>

# %%
#age_cholester
df.plot.scatter(x = 'age', y = 'cholester')
# Out:
# <AxesSubplot:xlabel='age', ylabel='cholester'>

# %%
#age_cholester
df.plot.scatter(x='age', y='taux_max', color='tab:green')
# Out:
# <AxesSubplot:xlabel='age', ylabel='taux_max'>

# %%
#age_depression
df.plot.scatter(x='age', y='depression', color='tab:blue')
# Out:
# <AxesSubplot:xlabel='age', ylabel='depression'>

# %%
#age_pic
df.plot.scatter(x='age', y='pic')
# Out:
# <AxesSubplot:xlabel='age', ylabel='pic'>

# %%
#pression-cholester
df.plot.scatter(x='pression', y='cholester', color='tab:orange')
# Out:
# <AxesSubplot:xlabel='pression', ylabel='cholester'>

# %%
#pression-cholester
df.plot.scatter(x='pression', y='taux_max')
# Out:
# <AxesSubplot:xlabel='pression', ylabel='taux_max'>

# %%
#pression-depression
df.plot.scatter(x='pression', y='depression', color='tab:red')
# Out:
# <AxesSubplot:xlabel='pression', ylabel='depression'>

# %%
#pression-pic
df.plot.scatter(x='pression', y='pic')
# Out:
# <AxesSubplot:xlabel='pression', ylabel='pic'>

# %%
#cholester-taux_max
df.plot.scatter(x='cholester', y='taux_max')
# Out:
# <AxesSubplot:xlabel='cholester', ylabel='taux_max'>

# %%
#cholester-depression
df.plot.scatter(x='cholester', y='depression')
# Out:
# <AxesSubplot:xlabel='cholester', ylabel='depression'>

# %%
#cholester-pic
df.plot.scatter(x='cholester', y='pic')
# Out:
# <AxesSubplot:xlabel='cholester', ylabel='pic'>

# %%
#taux_max-depression
df.plot.scatter(x='taux_max', y='depression')
# Out:
# <AxesSubplot:xlabel='taux_max', ylabel='depression'>

# %%
df.plot.scatter(x='cholester', y='depression')
# Out:
# <AxesSubplot:xlabel='cholester', ylabel='depression'>

# %%
#depression-pic
df.plot.scatter(x='depression', y='pic')
# Out:
# <AxesSubplot:xlabel='depression', ylabel='pic'>

# %% [markdown]
# ## Affichage variable qualit - qualit

# %%
#sexe-sucre
df.plot.scatter(x='sexe', y='sucre')
# Out:
# <AxesSubplot:xlabel='sucre', ylabel='electro'>

# %%
#sexe-electro
df.plot.scatter(x='sexe', y='electro')
# Out:
# <AxesSubplot:xlabel='sexe', ylabel='electro'>

# %%
#sexe-angine
df.plot.scatter(x='sexe', y='angine')
# Out:
# <AxesSubplot:xlabel='sexe', ylabel='angine'>

# %%
#sexe-coeur
df.plot.scatter(x='sexe', y='coeur')
# Out:
# <AxesSubplot:xlabel='sexe', ylabel='coeur'>

# %%
#sucre-electro
df.plot.scatter(x='sucre', y='electro')
# Out:
# <AxesSubplot:xlabel='sucre', ylabel='electro'>

# %%
#sucre-angine
df.plot.scatter(x='sucre', y='angine')
# Out:
# <AxesSubplot:xlabel='sucre', ylabel='angine'>

# %%
#sucre-coeur
df.plot.scatter(x='sucre', y='coeur')
# Out:
# <AxesSubplot:xlabel='sucre', ylabel='coeur'>

# %%
#electro-angine
df.plot.scatter(x='electro', y='angine')
# Out:
# <AxesSubplot:xlabel='electro', ylabel='angine'>

# %%
#electro-coeur
df.plot.scatter(x='electro', y='coeur')
# Out:
# <AxesSubplot:xlabel='electro', ylabel='coeur'>

# %%
#angine-coeur
df.plot.scatter(x='angine', y='coeur')
# Out:
# <AxesSubplot:xlabel='angine', ylabel='coeur'>

# %% [markdown]
# ## Variables Quantit - Qualit

# %%
#age-sexe
df.plot.scatter(x='age', y='sexe')
# Out:
# <AxesSubplot:xlabel='age', ylabel='sexe'>

# %%
#age-pression 
df.plot.scatter(x='age', y='pression')
# Out:
# <AxesSubplot:xlabel='age', ylabel='pression'>

# %%
#age-cholester
df.plot.scatter(x='age', y='cholester')
# Out:
# <AxesSubplot:xlabel='age', ylabel='cholester'>

# %%
#age-sucre
df.plot.scatter(x='age', y='sucre')
# Out:
# <AxesSubplot:xlabel='age', ylabel='sucre'>

# %%
#age-electro
df.plot.scatter(x='age', y='electro')
# Out:
# <AxesSubplot:xlabel='age', ylabel='electro'>

# %%
#age-taux_max
df.plot.scatter(x='age', y='taux_max')
# Out:
# <AxesSubplot:xlabel='age', ylabel='taux_max'>

# %%
#age-angine
df.plot.scatter(x='age', y='angine')
# Out:
# <AxesSubplot:xlabel='age', ylabel='angine'>

# %%
#age-pic
df.plot.scatter(x='age', y='pic')
# Out:
# <AxesSubplot:xlabel='age', ylabel='pic'>

# %%
#age-vaisseau
df.plot.scatter(x='age', y='vaisseau')
# Out:
# <AxesSubplot:xlabel='age', ylabel='vaisseau'>

# %%
#age-coeur
df.plot.scatter(x='age', y='coeur')
# Out:
# <AxesSubplot:xlabel='age', ylabel='coeur'>

# %% [markdown]
# # SEABORN

# %%
#visualisation du dataset
sns.pairplot(df)

# %% [markdown]
# ## Variable quantit - quantit

# %%
sns.scatterplot('age','pression', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='pression'>

# %%
sns.scatterplot('age','cholester', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='cholester'>

# %%
sns.scatterplot('age','taux_max', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='taux_max'>

# %%
sns.scatterplot('age','depression', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='depression'>

# %%
sns.scatterplot('age','pic', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='pic'>

# %%
sns.scatterplot('pression','cholester', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pression', ylabel='cholester'>

# %%
sns.scatterplot('pression','taux_max', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pression', ylabel='taux_max'>

# %%
sns.scatterplot('pression','depression', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pression', ylabel='depression'>

# %%
sns.scatterplot('pression','pic', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pression', ylabel='pic'>

# %%
sns.scatterplot('cholester','taux_max', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cholester', ylabel='taux_max'>

# %%
sns.scatterplot('cholester','taux_max', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cholester', ylabel='taux_max'>

# %%
sns.scatterplot('cholester','depression', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cholester', ylabel='depression'>

# %%
sns.scatterplot('cholester','pic', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cholester', ylabel='pic'>

# %%
sns.scatterplot('taux_max','depression', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='taux_max', ylabel='depression'>

# %%
sns.scatterplot('taux_max','pic', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='taux_max', ylabel='pic'>

# %%
sns.scatterplot('depression','pic', data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='depression', ylabel='pic'>

# %% [markdown]
# ## Variable Quantitative - Qualitative

# %%
sns.boxplot(x='sexe', y='age', data=df, hue='sexe')
# Out:
# <AxesSubplot:xlabel='sexe', ylabel='age'>
